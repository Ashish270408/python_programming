# %% [markdown]
# Q1

# %%
class Student:
    school_name="UPES"
    
    def __init__(self, name, age):
        self.name=name
        self.age=age

s1=Student("Ashish", 18)
s2=Student("Tanveer", 25)

print("School of student 1:", s1.school_name)
print("School of student 2:", s2.school_name)

print(f"Name of student 1: {s1.name}, Age: {s1.age}")
print(f"Name of student 2: {s2.name}, Age: {s2.age}")
# Out:
# School of student 1: UPES
# School of student 2: UPES
# Name of student 1: Ashish, Age: 18
# Name of student 2: Tanveer, Age: 25

# %% [markdown]
# Q2

# %%
class Employee:
    company="ABC Ltd"
    
    def __init__(self, name, salary):
        self.name=name
        self.salary=salary
    
    def show_details(self):
        print(f"Company: {Employee.company}, Name: {self.name}, Salary: {self.salary}")
    
    @classmethod
    def change_company(cls, new_name):
        cls.company=new_name

e1=Employee("Ashish", 22000)
e2=Employee("Tanveer", 18000)
print("\nBefore change: \n")
e1.show_details()
e2.show_details()

Employee.change_company("XYZ LTD")
print("\nAfter Change: \n")
e1.show_details()
e2.show_details()
# Out:
# Before change:
#
# Company: ABC Ltd, Name: Ashish, Salary: 22000
# Company: ABC Ltd, Name: Tanveer, Salary: 18000
#
# After Change:
#
# Company: XYZ LTD, Name: Ashish, Salary: 22000
# Company: XYZ LTD, Name: Tanveer, Salary: 18000

# %% [markdown]
# Q3

# %%
class MathHelper:
    @staticmethod
    def is_even(num):
        return num%2==0

o1=MathHelper()
print(o1.is_even(8))
print(o1.is_even(11))
# Out:
# True
# False

# %% [markdown]
# Q4

# %%
class BankAccount:
    def __init__(self, name, balance):
        self.name=name
        self.__balance=balance
    
    def deposit(self, amount):
        if amount>0:
            self.__balance+=amount
            print(amount, "Deposited!!")
        else:
            print("Wrong Amount!!")
    
    def withdraw(self, amount):
        if amount>self.__balance:
            print("Insufficent Balance")
        else:
            self.__balance-=amount
            print(amount, "Withdrawn")
    
    def show_balance(self):
        print("Current Balance:", self.__balance)

o1=BankAccount("Ashish", 20000)
o1.deposit(1000)
o1.withdraw(11000)
o1.withdraw(11000)
o1.show_balance()
# Out:
# 1000 Deposited!!
# 11000 Withdrawn
# Insufficent Balance
# Current Balance: 10000

# %% [markdown]
# Q5

# %%
class Student:
    """This is a class which creates student object"""
    
    def __init__(self, name):
        self.name=name

print("Class Name: ", Student.__name__)
print("Docstring: ", Student.__doc__)
print("Module: ", Student.__module__)
print("Dictionary: ", Student.__dict__)
# Out:
# Class Name:  Student
# Docstring:  This is a class which creates student object
# Module:  __main__
# Dictionary:  {'__module__': '__main__', '__firstlineno__': 1, '__doc__': 'This is a class which creates student object', '__init__': <function Student.__init__ at 0x000002064C622AC0>, '__static_attributes__': ('name',), '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}

# %% [markdown]
# Q6

# %%
class Product:
    def __init__(self, name, price):
        self.name=name
        self.price=price
    
    def __str__(self):
        return f"Name: {self.name}, Price: {self.price}"
    
    def __add__(self, other):
        return self.price+other.price
    
    def __eq__(self, other):
        return self.price==other.price

p1=Product("Laptop", 50000)
p2=Product("Phone", 30000)
p3=Product("Tablet", 50000)

print(p1)
print(p1+p2)
print(p1==p3)
print(p1==p2)
# Out:
# Name: Laptop, Price: 50000
# 80000
# True
# False
