# %% [markdown]
# Q- Explain in simple pseudocode how upper() function is not s function but a method of str class. (10 Marks)
#
# ```CLASS String
# METHOD upper()
#         FOR each character in the string
#             IF character is lowercase
#                 convert it to uppercase
#             ELSE
#                 keep it unchanged
#         RETURN new string
# END CLASS

# %% [markdown]
# Q- Explain the diff btween method and object.

# %%
len("python")
# Out:
# 6
