# %%
a=5
a++
print(a)
# Out:
#   Cell In[1], line 2
#     a++
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # how do u zip 4 lists using enumerator?

# %% [markdown]
# # [Do dsa challenge](https://github.com/vibhug0077/DSA_Python_Easy_21Day/blob/main/day1/DAS%20Easy%2021%20Days%20(5days%20Each)%20Python.md#1-two-sum)
