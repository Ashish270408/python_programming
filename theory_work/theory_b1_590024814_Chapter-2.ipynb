# %%
l=[4, 6, 2, 8, "A", "a", "Z"]
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 l=[4, 6, 2, 8, "A", "a", "Z"]
# ----> 2 l.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
