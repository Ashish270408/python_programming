# %% [markdown]
# # **Day-11 of 2nd Challenge**

# %% [markdown]
# 1. Create a class `Visitor`:
#
# - class variable: `total_visitors = 0`
# - instance variable: `name`
#
# 👉 Every time a new object is created:
#
# - increment `total_visitors`
#
# 👉 Task:
#
# - Create 3 visitors
# - Print total visitors

# %% [markdown]
# 2. Create class `Product`:
#
# - attributes: `name`, `price`
#
# 👉 Add method:
#
# - `is_expensive(other_product)`
# - returns True if current product price is higher
#
# 👉 Task:
#
# - Compare 2 products

# %% [markdown]
# 3. Create class `Cart`:
#
# - attribute: `items` (list)
#
# 👉 Methods:
#
# - `add_item(item)`
# - `remove_item(item)` (only if exists)
# - `show_items()`
#
# 👉 Task:
#
# - Add 3 items
# - Remove 1
# - Print remaining

# %% [markdown]
# 4. Create:
#
# - class `Employee` → method `get_bonus()` (default = 0)
# - class `Manager` → bonus = 20% salary
# - class `Intern` → bonus = 5% salary
#
# 👉 Task:
#
# - Store different employee types in a list
# - Loop and print bonuses
