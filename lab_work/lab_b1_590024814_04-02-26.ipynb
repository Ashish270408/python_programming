# %%
import numpy as np
a=[1, 2, 3, 4]
b=[5, 6, 7, 8]
target=12
for i in a:
    for j in b:
        if(i+j==target):
            print(i, j)
            break
# Out:
# 4 8

# %% [markdown]
# read the dsa file of how to add two sum using function

# %%
l=[]
l=list(map(int, input("Enter integers with space: ").split()))
dict={0:0, 1:0, 2:0, 3:0}
for i in l:
        dict[i]=dict[i]+1
for k in dict:
    print(k, "occured", dict[k], "times")
# Out:
# 0 occured 1 times
# 1 occured 1 times
# 2 occured 1 times
# 3 occured 1 times

# %% [markdown]
# 2. **Create a tuple to store n numeric values and find the average of all values.**

# %%
l=tuple(map(int, input("Enter elements: ").split()))
sum=0
for i in l:
    sum+=i
avg=sum/len(l)
print(avg)
# Out:
# 3.0

# %% [markdown]
# 3. **WAP to input a list of scores for N students in a list data type. Find the score of the runner-up and print the output.**
# **Sample Input**
# **N = 5**
# **Scores= 2 3 6 6 5**
# **Sample output**
# **5**
# ***Note*: Given list is [2, 3, 6, 6, 5]. The maximum score is 6, second maximum is 5. Hence, we print 5 as the runner-up score.**

# %%
l=list(map(int, input("Enter elements: ").split()))
l=sorted(l, reverse=True)
max=l[0]
for i in l:
    if i<max:
        sec_max=i
        break
print("Runner-up score is", sec_max)
# Out:
# Runner-up score is 5
