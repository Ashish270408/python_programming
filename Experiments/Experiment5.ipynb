# %% [markdown]
# # **Experiment 5: String and Sets**
# 1. **Write a program to count and display the number of capital letters in a given string.**

# %%
a=input("Enter string: ")
count=0
for i in a:
    if i>='A' and i<='Z':
        count+=1
print("Total capital letters in given string", a, "are", count)
# Out:
# Total capital letters in given string Ashish are 1

# %% [markdown]
# 2. **Count total number of vowels in a given string.**

# %%
a=input("Enter string: ")
count=0
a=a.upper()
for i in a:
    if i in ['A', 'E', 'I', 'O', 'U']:
        count+=1
print("Total vowels in string", a, "are", count)
# Out:
# Total vowels in string ASHISH are 2

# %% [markdown]
# 3. **Input a sentence and print words in separate lines.**

# %%
a=input("Enter sentence: ")
words=a.split()
for i in words:
    print(i)
# Out:
# how
# are
# you?

# %% [markdown]
# 4. **WAP to enter a string and a substring. You have to print the number of times that the substring occurs in the given string. String traversal will take place from left to right, not from right to left.**
# **Sample Input**
# **ABCDCDC**
# **CDC**
# **Sample Output**
# **2**

# %%
a=input("Enter string: ")
b=input("Enter substring: ")
num=a.count(b)
print("Number of substrings", b, "in string", a, "are", num)
# Out:
# Number of substrings sh in string Ashish are 2

# %% [markdown]
# 5. **Given a string containing both upper and lower-case alphabets. Write a Python program to count the number of occurrences of each alphabet (case insensitive) and display the same.**
# **Sample Input**
# **ABaBCbGc**
# **Sample Output**
# **2A**
# **3B**
# **2C**
# **1G**

# %%
a=input("Enter string: ")
a=a.upper()
count={}
for ch in a:
    if ch.isalpha():
        count[ch]=count.get(ch, 0)+1
keys=sorted(count)
for ch in keys:
    print(str(count[ch])+ch)
# Out:
# 1D
# 1E
# 1H
# 3L
# 2O
# 1R
# 1W

# %% [markdown]
# 6. **Program to count the number of unique words in a given sentence using sets.**

# %%
a=input("Enter string: ")
s=set()
for ch in a:
    s.add(ch)
print("Number of unique characters are", len(s))
# Out:
# Number of unique characters are 4

# %% [markdown]
# 7. **Create 2 sets s1 and s2 of n fruits each by taking input from user and find:**
# **a. Fruits which are in both sets s1 and s2**
# **b. Fruits only in s1 but not in s2**
# **c. Count of all fruits from s1 and s2**

# %%
s1=set(input("Enter fruits name: ").split())
s2=set(input("Enter fruits name: ").split())
print("Fruits which are in both s1 and s2 are", s1&s2)
print("Fruits only in s1 but not in s2 are", s1-s2)
print("Count of fruits in both s1 and s2 are", s1|s2)
# Out:
# Fruits which are in both s1 and s2 are {'guava', 'apple'}
# Fruits only in s1 but not in s2 are {'banana', 'orange'}
# Count of fruits in both s1 and s2 are {'grapes', 'guava', 'banana', 'papaya', 'orange', 'apple'}

# %% [markdown]
# 8. **Take two sets and apply various set operations on them:**
# **S1 = {Red, yellow, orange, blue}**
# **S2 = {violet, blue, purple}**

# %%
s1={'Red', 'Yellow', 'Orange', 'Blue'}
s2={'Violet', 'Blue', 'Purple'}
print("Union of both sets is", s1|s2)
print("Intersection of both sets is", s1&s2)
print("Elements in s1 but not in s2 is", s1-s2)
# Out:
# Union of both sets is {'Red', 'Blue', 'Orange', 'Yellow', 'Violet', 'Purple'}
# Intersection of both sets is {'Blue'}
# Elements in s1 but not in s2 is {'Red', 'Yellow', 'Orange'}
